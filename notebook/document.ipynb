# %% [markdown]
# ### Data Ingestion

# %%
###Documents Structure

from langchain_core.documents import Document
# Out:
# /Users/omar/first_rag/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
doc=Document(
    page_content="This is the main text content of the document. I using to test RAG",
    metadata={
            "author": "John Doe",
            "date": "2023-10-05"
            }
)
doc
# Out:
# Document(metadata={'author': 'John Doe', 'date': '2023-10-05'}, page_content='This is the main text content of the document. I using to test RAG')
